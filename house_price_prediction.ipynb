# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the dataset
x = np.array([30, 50, 70])  # House Size in m²
y = np.array([60, 100, 140])  # Price in $1000s

# Initialize parameters
theta_0 = 0  # Intercept
theta_1 = 0  # Slope
learning_rate = 0.0001  # Learning rate
iterations = 100  # Number of iterations
m = len(x)  # Number of data points
cost_history = []  # Store cost values for each iteration

# Perform Gradient Descent
for i in range(iterations):
    # Compute predictions
    y_pred = theta_0 + theta_1 * x
    
    # Compute errors
    errors = y_pred - y
    
    # Compute cost (Mean Squared Error)
    cost = (1/(2*m)) * np.sum(errors**2)
    cost_history.append(cost)  # Store cost value
    
    # Compute gradients
    grad_theta_0 = (1/m) * np.sum(errors)
    grad_theta_1 = (1/m) * np.sum(errors * x)
    
    # Update parameters
    theta_0 = theta_0 - learning_rate * grad_theta_0
    theta_1 = theta_1 - learning_rate * grad_theta_1

    print(f"Iteration {i+1}: theta_0 = {theta_0:.4f}, theta_1 = {theta_1:.4f}, Cost = {cost:.4f}")

# Make a prediction for a 90 m² house
house_size = 90
predicted_price = theta_0 + theta_1 * house_size
print(f"Predicted price for a {house_size} m² house: ${predicted_price:.2f}K")
# Out:
# Iteration 1: theta_0 = 0.0100, theta_1 = 0.5533, Cost = 5533.3333
# Iteration 2: theta_0 = 0.0172, theta_1 = 0.9535, Cost = 2894.3782
# Iteration 3: theta_0 = 0.0225, theta_1 = 1.2430, Cost = 1513.9925
# Iteration 4: theta_0 = 0.0262, theta_1 = 1.4523, Cost = 791.9398
# Iteration 5: theta_0 = 0.0290, theta_1 = 1.6037, Cost = 414.2482
# Iteration 6: theta_0 = 0.0310, theta_1 = 1.7132, Cost = 216.6852
# Iteration 7: theta_0 = 0.0324, theta_1 = 1.7924, Cost = 113.3438
# Iteration 8: theta_0 = 0.0334, theta_1 = 1.8497, Cost = 59.2879
# Iteration 9: theta_0 = 0.0342, theta_1 = 1.8911, Cost = 31.0124
# Iteration 10: theta_0 = 0.0347, theta_1 = 1.9211, Cost = 16.2220
# Iteration 11: theta_0 = 0.0351, theta_1 = 1.9427, Cost = 8.4854
# Iteration 12: theta_0 = 0.0354, theta_1 = 1.9584, Cost = 4.4386
# Iteration 13: theta_0 = 0.0356, theta_1 = 1.9697, Cost = 2.3218
# Iteration 14: theta_0 = 0.0357, theta_1 = 1.9779, Cost = 1.2145
# Iteration 15: theta_0 = 0.0358, theta_1 = 1.9839, Cost = 0.6353
# Iteration 16: theta_0 = 0.0359, theta_1 = 1.9881, Cost = 0.3323
# Iteration 17: theta_0 = 0.0360, theta_1 = 1.9912, Cost = 0.1739
# Iteration 18: theta_0 = 0.0360, theta_1 = 1.9935, Cost = 0.0910
# Iteration 19: theta_0 = 0.0361, theta_1 = 1.9951, Cost = 0.0476
# Iteration 20: theta_0 = 0.0361, theta_1 = 1.9963, Cost = 0.0249
# Iteration 21: theta_0 = 0.0361, theta_1 = 1.9971, Cost = 0.0131
# Iteration 22: theta_0 = 0.0361, theta_1 = 1.9977, Cost = 0.0069
# Iteration 23: theta_0 = 0.0361, theta_1 = 1.9982, Cost = 0.0036
# Iteration 24: theta_0 = 0.0361, theta_1 = 1.9985, Cost = 0.0019
# Iteration 25: theta_0 = 0.0361, theta_1 = 1.9987, Cost = 0.0010
# Iteration 26: theta_0 = 0.0361, theta_1 = 1.9989, Cost = 0.0006
# Iteration 27: theta_0 = 0.0361, theta_1 = 1.9990, Cost = 0.0003
# Iteration 28: theta_0 = 0.0361, theta_1 = 1.9991, Cost = 0.0002
# Iteration 29: theta_0 = 0.0361, theta_1 = 1.9992, Cost = 0.0001
# Iteration 30: theta_0 = 0.0361, theta_1 = 1.9992, Cost = 0.0001
# Iteration 31: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 32: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 33: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 34: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 35: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 36: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 37: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 38: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 39: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 40: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 41: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 42: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 43: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 44: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 45: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 46: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 47: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 48: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 49: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 50: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 51: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 52: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 53: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 54: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 55: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 56: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 57: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 58: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 59: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 60: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 61: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 62: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 63: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 64: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 65: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 66: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 67: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 68: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 69: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 70: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 71: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 72: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 73: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 74: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 75: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 76: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 77: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 78: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 79: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 80: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 81: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 82: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 83: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 84: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 85: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 86: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 87: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 88: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 89: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 90: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 91: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 92: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 93: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 94: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 95: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 96: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 97: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 98: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 99: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Iteration 100: theta_0 = 0.0361, theta_1 = 1.9993, Cost = 0.0001
# Predicted price for a 90 m² house: $179.98K

# %%
# Plot Training Data & Regression Line
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='Training Data')
plt.plot(x, theta_0 + theta_1 * x, color='red', label='Regression Line')
plt.xlabel("House Size (m²)")
plt.ylabel("Price ($1000s)")
plt.title("Linear Regression Fit")
plt.legend()
plt.show()

# Plot Cost Function Convergence
plt.figure(figsize=(8, 6))
plt.plot(range(1, iterations+1), cost_history, marker='o', linestyle='-')
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.title("Cost Function Convergence")
plt.show()
